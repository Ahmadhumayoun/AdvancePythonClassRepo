# %%
from readline import clear_history


def addition(n1 , n2):
    s = n1 + n2
    return s

# %%
class userProfile:
    def commCleaner(self,price):
        price.replace(",","")
    def currencyCleaner(self,currency):
        currency.replace("$","")

# %%
up  = userProfile()
up.firstname("Ahmad")
# Out:
# Ahmad

# %%
up.currencyCleaner(up.commCleaner(""))
# Out:
# This is a car wheel

# %%
class userProfile:
    def __init__(self,userName,userAge):
        self.userName = userName
        self.userAge = userAge


    def addLastName(self,lastName):
        self.userName = self.userName + " " + lastName
    def printUserName(self):
        print(self.userName)
    def printUserAge(self):
        print(f"{self.userName} is {20-18}")
    def printUserAddress(self):
        print(f"{self.userName} lives in New York")

# %%
u = userProfile("Ahmad",25)
u.addLastName("humayoun")
u.printUserName()
u.printUserAge()
u.printUserAddress()
# Out:
# Ahmad humayoun
# Ahmad humayoun is 2
# Ahmad humayoun lives in New York

# %%
class pclass:

    def parentClassFunction(self):
        print("this function is from parent class")

class cClass(pclass):

    def childClassFunction (self):
        print("this function is from child class")

Child = cClass()
Child.parentClassFunction()
Child.childClassFunction()
# Out:
# this function is from parent class
# this function is from child class

# %%
class parentClass:
    def __init__(self,_name):
        self.__name = _name

    def publicFunc(self):
        print("this function is from parent class")
    def privateFunc(self):
        print("this function is from parent class")

class childClass(parentClass):
    def __init__(self,name,age):
        super().__init__(name)
        self.age = age

    def chilClassFunc(self):
        print("this function is from child class")
class grandChildClass(childClass):
    def __init__(self,name,age):
        super().__init__(name,age)
        self.age = age

# %%
ca = grandChildClass("Ahmad",20)

# %%
ca.privateFunc()
# Out:
# this function is from parent class

# %%
class parentClass1:
    def polyFunction(self):
        print("this function is from parent class")
class childClass1(parentClass1):
    def polyFunction(self):
        print("this function is from child class")

# %%
c = childClass1()
c.polyFunction()
# Out:
# this function is from child class

# %%
#Encapsulation
#Inheritence
#Polymorphism
#Access modifiers

# %%
#Make a class "UserProfile" with constructor as UserName,Age & and gender and 3 functions
#Make another child Class inherited from "UserProfile" with its own two more constructor and 2 more functions
# Do implement the polymorphism

# %%
class UserProfile:
    def __init__(self,userName,userAge,userGender):
        self.userName = userName
        self.userAge = userAge
        self.__userGender = userGender
    def printUserName(self):
        print(self.userName)
    def printUserAge(self):
        print(f"{self.userName} is {20-18}")
    def printUserAddress(self):
        print(f"{self.userName} lives in New York")

class childClass(userProfile):
    def __init__(self,userName,userAge,userGender,userAddress,userCity):
        super().__init__(userName,userAge,userGender)
        self.userAddress = userAddress
        self.userCity = userCity
    def printUserAddress(self):
        print(f"{self.userName} lives in New York")

# %%
up = UserProfile("Ahmad",25,"male")

# %%
up.printUserAddress()
# Out:
# Ahmad lives in New York

# %%
from abc import  ABC,abstractmethod

class abClass(ABC):

    def funcP(self):
        print("This is a function from parent class")
    @abstractmethod
    def compulsoryFunction(self):
        print('This is compulsory from Parent')
class abcClass(abClass):
    def funcCh(self):
        print("This is a function from child class")

    def compulsoryFunction(self):
        pass
c = abcClass()
c.funcP()
c.funcCh()
c.compulsoryFunction()
# Out:
# This is a function from parent class
# This is a function from child class
