# %%
import pandas as pd

# %%
#Series

# %%
sr = pd.Series(["Ahmad","Python","Class"],index=["*","=>","!"])

# %%
sr
# Out:
# *      Ahmad
# =>    Python
# !      Class
# dtype: str

# %%
userData = {"name":["Ahmad","python","Class"],"age":[25,26,27]}

# %%
userData
# Out:
# {'name': ['Ahmad', 'python', 'Class'], 'age': [25, 26, 27]}

# %%
df = pd.DataFrame(userData)

# %%
df
# Out:
#      name  age
# 0   Ahmad   25
# 1  python   26
# 2   Class   27

# %%
df.to_csv("ClasFirstTable.csv")

# %%
dfItems = pd.read_excel("C:\\CurrentUnityProjects\\NavClassAdvancePython\\AdvancePythonClassRepo\\PandasTabularData\\VendorProducts.xlsx",sheet_name="Items")
dfCollections= pd.read_excel("C:\\CurrentUnityProjects\\NavClassAdvancePython\\AdvancePythonClassRepo\\PandasTabularData\\VendorProducts.xlsx",sheet_name="Collections")

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfCollections
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name Color Code       Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420,000د.ع
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300,000د.ع
# 2                              The Glow Stick    #F3D5C6   19,750د.ع
# ...

# %%
print(type(dfItems))
print(type(dfItems["Secondary Description"]))
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.Series'>

# %%
#Name
#Price
#Brand
#Barcode

# %%
dfItems["Price"]
# Out:
# 0         25,000د.ع
# 1        300,000د.ع
# 2         30,000د.ع
# 3             00د.ع
# 4         15,000د.ع
#             ...
# 24697     16,500د.ع
# 24698     12,000د.ع
# 24699     10,500د.ع
# 24700     15,000د.ع
# 24701     22,500د.ع
# Name: Price, Length: 24702, dtype: str

# %%
x =" 25,000د.ع"
25000
# Out:
# 25000

# %%
dfItems.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24702 entries, 0 to 24701
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Picture                    24300 non-null  str
#  1   Id                         24702 non-null  int64
#  2   Name                       24702 non-null  str
#  3   Secondary Name             24702 non-null  str
#  4   Barcode                    22041 non-null  str
#  5   Code                       21993 non-null  str
#  6   Price                      24702 non-null  str
#  7   Description                24645 non-null  str
#  8   Secondary Description      24644 non-null  str
#  9   Sub Description            24601 non-null  str
#  10  Secondary Sub Description  4 non-null      str
#  11  Menu                       24699 non-null  str
#  12  Brand                      24699 non-null  str
#  13  Secondary Brand            24696 non-null  str
# ...

# %%
dfItems.describe()
# Out:
#                   Id
# count   24702.000000
# mean   330583.440936
# std     12701.598678
# min    314991.000000
# 25%    321257.250000
# 50%    327496.500000
# 75%    334544.750000
# max    390188.000000

# %%
dfItems.head()
# Out:
#                                              Picture      Id  \
# 0  https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1  https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2  https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3  https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4  https://www.storeakmedia.com/storeak-erp/Store...  390177
#
#                                     Name  \
# 0             زيت الشفاه بليجر 001، 5 مل
# 1   عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2  سيروم الشعر لفروة الرأس سيابوري 20 مل
# 3         عطر جانيميد اودي بارفيوم 50 مل
# 4    جل تصفيف الحواجب مع الببتيدات 15 مل
#
#                           Secondary Name        Barcode Code       Price  \
# 0             Pleasure Lip Oil 001, 5 ml  8011607402304  NaN   25,000د.ع
# 1       Bleu De Chanel L'Exclusif Parfum            NaN  NaN  300,000د.ع
# 2        Seapuri Scalpy Hair Serum 20 ml  8809934860870  NaN   30,000د.ع
# ...

# %%
dfItems.tail()
# Out:
#                                                  Picture      Id  \
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 24697        معطر الشعر والجسم بالليمون والماتشا 150 مل
# 24698  معطر الشعر والجسم بالفلفل الوردي والليتشي 150 مل
# 24699         ماسكارا جلام اند دول تعزز نمو الرموش 8 مل
# 24700                        مست الجسم باشن فروت 150 مل
# 24701               ماسكارا فائقة الكثافة (1أسود) 15 مل
#
#                                           Secondary Name        Barcode Code  \
# 24697              Lime & Matcha Hair & Body Mist 150 ml  5028197838058    0
# 24698       Pink Pepper & Lychee Hair & Body Mist 150 ml  5028197930516    0
# ...

# %%
dfItems.fillna("")
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems[["Name"]].fillna("")
# Out:
#                                                    Name
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2                 سيروم الشعر لفروة الرأس سيابوري 20 مل
# 3                        عطر جانيميد اودي بارفيوم 50 مل
# 4                   جل تصفيف الحواجب مع الببتيدات 15 مل
# ...                                                 ...
# 24697        معطر الشعر والجسم بالليمون والماتشا 150 مل
# 24698  معطر الشعر والجسم بالفلفل الوردي والليتشي 150 مل
# 24699         ماسكارا جلام اند دول تعزز نمو الرموش 8 مل
# 24700                        مست الجسم باشن فروت 150 مل
# 24701               ماسكارا فائقة الكثافة (1أسود) 15 مل
#
# [24702 rows x 1 columns]

# %%
#Make a data Frame of UserName /  Age / Class
# Save file as userData.csv

# %%
UserDataDictionary = {"Name":["Ahmad","Python","Class"],"Age":[25,26,27],"Class":["A","B","C"]}

# %%
df = pd.DataFrame(UserDataDictionary)

# %%
df.to_csv("UserData.csv",index=False)

# %%
UserDF = pd.read_csv("UserData.csv")

# %%
UserDF
# Out:
#      Name  Age Class
# 0   Ahmad   25     A
# 1  Python   26     B
# 2   Class   27     C

# %%
currentrowNumber = len(UserDF["Name"])
UserDF.loc[currentrowNumber] = ["Ali","25","A"]

# %%
UserDF1 = UserDF

# %%
UserDF1.to_csv("UserData.csv",index=False)

# %%
UserDF1
# Out:
#      Name Age Class
# 0   Ahmad  25     A
# 1  Python  26     B
# 2   Class  27     C
# 3     Ali  25     A

# %%
# Create banking System
# Ask user to Create Account or Check or withDraw or deposit
# Use while true for this process
# Lets say user created account = 5000
# Dictionary Example = {"UserNames":[a,b,c,d,e],"Age":[1,2,3,4],"Balance":[1000,2000,3000,4000]
#Create a csv and store data in therep

# %%
"""
Create a Simple Banking System in Python that stores account data in a CSV file using the Pandas library. The program should be menu-driven and continuously run until the user chooses to exit. The CSV file should contain the columns AccountNumber, Name, and Balance. The program must support the following operations:
	1.	Create Account – Ask the user for account number, customer name, and initial balance, then store the record in the CSV file.
	2.	Deposit Money – Ask for account number and deposit amount, find the account, and increase the balance.
	3.	Withdraw Money – Ask for account number and withdrawal amount, check if the account has sufficient balance, and subtract the amount if possible. If not, display “Insufficient Balance.”
	4.	Check Balance – Ask for the account number and display the current balance of that account.
	5.	Exit – Terminate the program when the user selects this option.

The program should read data from the CSV file, update it when transactions occur, and save the updated data back to the file.
"""
# Out:
# '\nCreate a Simple Banking System in Python that stores account data in a CSV file using the Pandas library. The program should be menu-driven and continuously run until the user chooses to exit. The CSV file should contain the columns AccountNumber, Name, and Balance. The program must support the following operations:\n\t1.\tCreate Account – Ask the user for account number, customer name, and initial balance, then store the record in the CSV file.\n\t2.\tDeposit Money – Ask for account number and deposit amount, find the account, and increase the balance.\n\t3.\tWithdraw Money – Ask for account number and withdrawal amount, check if the account has sufficient balance, and subtract the amount if possible. If not, display “Insufficient Balance.”\n\t4.\tCheck Balance – Ask for the account number and display the current balance of that account.\n\t5.\tExit – Terminate the program when the user selects this option.\n\nThe program should read data from the CSV file, update it when transac
# ...

# %%
import random as rd
while True:
    choice = int(input("Enter 1 for account Opening \n Enter 2 for Balance Check \n Enter 3 for WithDrawl \n Enter 4 for Deposit: \n Enter 5 for Exit:"))
    if choice ==1:
        userDB = pd.read_csv("Bank.csv")
        userName = input("Enter User Name:")
        accNo = rd.randint(10000,99999)
        balance = 5000
        newUserDataList = [accNo,userName,balance]
        currentrowNumber = len(userDB["AccountNumber"])
        userDB.loc[currentrowNumber] = newUserDataList
        userDB.to_csv("Bank.csv",index=False)
        print("Account Created")
    elif choice ==2:
        userDB = pd.read_csv("Bank.csv")
        accNo = int(input("Enter Account Number:"))
        if accNo not in list(userDB["AccountNumber"]):
            print("Account Number Not Found")
            continue
        for i in range(len(userDB)):
            if userDB["AccountNumber"][i] == accNo:
                nm = userDB["FullName"][i]
                print(f"Welcome {nm} \nYour Balance is {userDB['Balance'][i]}")

    elif choice ==3:
        userDB = pd.read_csv("Bank.csv")
        accNo = int(input("Enter Account Number:"))
        if accNo not in list(userDB["AccountNumber"]):
            print("Account Number Not Found")
            continue
        for i in range(len(userDB)):
            if userDB["AccountNumber"][i] == accNo:
                nm = userDB["FullName"][i]
                amount2Wtihdraw = int(input("Enter Amount to Withdraw:"))
                userDB['Balance'][i] = userDB['Balance'][i] - amount2Wtihdraw
                # userDB['Balance'][i] = newBalance
                print(f"Welcome {nm} \nYour new Balance is {userDB['Balance'][i]}")
                userDB.to_csv("Bank.csv",index=False)
    elif choice ==4:
        userDB = pd.read_csv("Bank.csv")
        accNo = int(input("Enter Account Number:"))
        if accNo not in list(userDB["AccountNumber"]):
            print("Account Number Not Found")
            continue
        for i in range(len(userDB)):
            if userDB["AccountNumber"][i] == accNo:
                nm = userDB["FullName"][i]
                amount2Wtihdraw = int(input("Enter Amount to Withdraw:"))
                userDB['Balance'][i] = userDB['Balance'][i] + amount2Wtihdraw
                # userDB['Balance'][i] = newBalance
                print(f"Welcome {nm} \nYour new Balance is {userDB['Balance'][i]}")
                userDB.to_csv("Bank.csv",index=False)
    elif choice ==5:
        print("Exiting")
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 3
#       1 import random as rd
#       2 while True:
# ----> 3     choice = int(input("Enter 1 for account Opening \n Enter 2 for Balance Check \n Enter 3 for WithDrawl \n Enter 4 for Deposit: \n Enter 5 for Exit:"))
#       4     if choice ==1:
#       5         userDB = pd.read_csv("Bank.csv")
#
# File C:\CurrentUnityProjects\NavClassAdvancePython\AdvancePythonClassRepo\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
# ...

# %%
userDictionary = {"AccountNumber":[10001],"FullName":["Ahmad"],"Balance":[5000]}
df = pd.DataFrame(userDictionary)
df
# Out:
#    AccountNumber FullName  Balance
# 0          10001    Ahmad     5000

# %%
df.to_csv("Bank.csv",index=False)

# %%
"""
user id = string
username = string
class = sstring
subjects = list


Student registration
Student information fetch
student information update
"""
# Out:
# '\nuser id = string\nusername = string\nclass = sstring\nsubjects = list\n\n\nStudent registration\nStudent information fetch\nstudent information update\n'

# %%
import pandas as pd

# %%
StudentAccountDictionary = {"StudentId":["10001","10002","10003"],"StudentName":["Ahmad","Ali","yth"],"StudentClass":["1","2","3"],"Subjects":[["Math","English","Science"],["Math","Chemistry","Science"],["islamicStudies","English","Physics"]]}

# %%
studentDF = pd.DataFrame(StudentAccountDictionary)

# %%
studentDF
# Out:
#   StudentId StudentName StudentClass                            Subjects
# 0     10001       Ahmad            1            [Math, English, Science]
# 1     10002         Ali            2          [Math, Chemistry, Science]
# 2     10003         yth            3  [islamicStudies, English, Physics]

# %%
studentDF.to_csv("StudentData.csv",index=False)

# %%
import random as r
while True:
    choice = input("Enter 1 for Student Registration \n Enter 2 for Student Information Fetch \n Enter 3 for Student Information Update \n Enter 4 for Exit:")
    if choice == "1":
        print("======Registering Student========")
        studentDF = pd.read_csv("StudentData.csv")
        studentId = r.randint(10000,99999)
        studentName = input("Enter Student Name:")
        studentClass = input("Enter Student Class:")
        subjects = ["Maths","English","Science"]
        currentrowNumber = len(studentDF["StudentId"])
        studentDF.loc[currentrowNumber] = [studentId,studentName,studentClass,subjects]
        studentDF.to_csv("StudentData.csv",index=False)

        print("======Registering Student========")

    elif choice =="2":
        print("======Student Information Fetch========")
        studentDF = pd.read_csv("StudentData.csv")
        studentId = int(input("Enter Student Id:"))
        if studentId not in list(studentDF["StudentId"]):
            print("Student Id Not Found")
            continue
        for i in range(len(studentDF)):
            if studentDF["StudentId"][i] == studentId:
                print(f"Student Name : {studentDF['StudentName'][i]}")
                print(f"Student Class : {studentDF['StudentClass'][i]}")
                print(f"Student Subjects : {studentDF['Subjects'][i]}")
        print("======Student Information Fetch========")
    elif choice =="3":
        print("======Student Information Update=======")
        studentDF = pd.read_csv("StudentData.csv")
        studentId = int(input("Enter Student Id:"))
        if studentId not in list(studentDF["StudentId"]):
            print("Student Id Not Found")
            continue
        for i in range(len(studentDF)):
            if studentDF["StudentId"][i] == studentId:
                print("What do you want to update?")
                updateChoice = input("Enter 1 for Student Name \n Enter 2 for Student Class \n Enter 3 for Student Subjects:")
                if updateChoice == "1":
                    newStudentName = input("Enter New Student Name:")
                    studentDF['StudentName'][i] = newStudentName
                    print(f"Student Name Updated to {newStudentName}")
                elif updateChoice == "2":
                    newStudentClass = input("Enter New Student Class:")
                    studentDF['StudentClass'][i] = newStudentClass
                    print(f"Student Class Updated to {newStudentClass}")
                elif updateChoice == "3":
                    subjectsChoice = input("Do you want to add subjects or remove subjects? Enter 1 for Add \n Enter 2 for Remove:")
                    if subjectsChoice == "1":
                        newSubjects = input("Enter New Subjects:")
                        studentDF['Subjects'][i].append(newSubjects)
                        print(f"Student Subjects Updated to {studentDF['Subjects'][i]}")
                    if subjectsChoice == "2":
                        subjectsToRemove = input("Enter Subjects to Remove:")
                        studentDF['Subjects'][i].remove(subjectsToRemove)
        print("======Student Information Update=======")
    elif choice =="4":
        print("Exiting")
        break
# Out:
# ======Registering Student========
# ======Registering Student========
# Exiting

# %%
dfItems.loc(0)
# Out:
#                                        Secondary Name       Price
# 1                    Bleu De Chanel L'Exclusif Parfum  300,000د.ع
# 2                     Seapuri Scalpy Hair Serum 20 ml   30,000د.ع
# 3                                  Ganymede EDP 50 ml       00د.ع
# 4               Brow Styling Gel With Peptides 15 ml    15,000د.ع
# 5                             Limitless Mascara 10 ml   15,000د.ع
# 6                                  Eyebrow Serum 5 ml   18,000د.ع
# 7                               Evadamo Mascara 10 ml   15,000د.ع
# 8                        Argan Oil Conditioner 300 ml    7,750د.ع
# 9                       Argan Oil Conditioner 1000 ml   15,500د.ع
# 10  Professional 1500 W Hair Dryer With 7 Attachments   65,000د.ع

# %%
questionare=pd.read_csv("QuestionareDummy.csv")

# %%
questionare
# Out:
#                                              Question  \
# 0   Which programming language is known as the 'mo...
# 1               What is the chemical symbol for Gold?
# 2            Which planet is known as the Red Planet?
# 3                          What does 'CPU' stand for?
# 4                Which ocean is the largest on Earth?
# 5   In Python, which library is commonly used for ...
# 6                          Who painted the Mona Lisa?
# 7                  What is the capital city of Japan?
# 8   Which component is responsible for long-term d...
# 9                     What is the square root of 144?
# 10  Which gas do plants primarily absorb for photo...
# 11  In Unity, which file extension is used for C# ...
# 12                What is the powerhouse of the cell?
# 13         Which country is the largest by land area?
# 14  What is the value of Pi rounded to two decimal...
# 15  Who is credited with inventing the World Wide ...
# ...

# %%
# Read Questions from above CSV
#Prepare 5-10 questions for a quiz
# A user will come and enter his/her name and take the quiz.
# One user cannot take quiz twice
# Save user score in a different csv named as student score
# if a student fail any question game will be end instantly

# %%
import random as r
randomnumberList = []
for i in range(10):
    while True:
        random10Numbers = r.randint(0,21)
        if random10Numbers not in randomnumberList:
            randomnumberList.append(random10Numbers)
            break
        else:
            continue

# %%
randomnumberList
# Out:
# [0, 20, 7, 11, 17, 6, 18, 1, 13, 15]

# %%
import pandas as pd
import random as r
# _Read Questions from above CSV_
# _Prepare 5-10 questions for a quiz_
# A user will come and enter his/her name and take the quiz.
# One user cannot take quiz twice
# Save user score in a different csv named as student score
# if a student fail any question game will be end instantly

import random as r

# %%
questionare = pd.read_csv("QuestionareDummy.csv")

# %%
questionare
# Out:
#                                              Question  \
# 0   Which programming language is known as the 'mo...
# 1               What is the chemical symbol for Gold?
# 2            Which planet is known as the Red Planet?
# 3                          What does 'CPU' stand for?
# 4                Which ocean is the largest on Earth?
# 5   In Python, which library is commonly used for ...
# 6                          Who painted the Mona Lisa?
# 7                  What is the capital city of Japan?
# 8   Which component is responsible for long-term d...
# 9                     What is the square root of 144?
# 10  Which gas do plants primarily absorb for photo...
# 11  In Unity, which file extension is used for C# ...
# 12                What is the powerhouse of the cell?
# 13         Which country is the largest by land area?
# 14  What is the value of Pi rounded to two decimal...
# 15  Who is credited with inventing the World Wide ...
# ...

# %%
randomnumberList = []
for i in range(10):
    while True:
        random10Numbers = r.randint(0,20)
        if random10Numbers not in randomnumberList:
            randomnumberList.append(random10Numbers)
            break
        else:
            continue
# for questionnumbers in randomnumberList:
#     print(questionare.loc[questionnumbers])


userdataDictionary = {"Names":["Ahmad","Ali","Pyth"],"Score":[9,10,5]}

userDataFrame = pd.DataFrame(userdataDictionary)

# %%
userDataFrame.to_csv("StudentScore.csv",index=False)

# %%
questionList = [] #Question
for eachRandomNumber in randomnumberList:
    # print(eachRandomNumber)
    singleQuestion = {"Question":questionare.loc[eachRandomNumber,"Question"],"OA":questionare.loc[eachRandomNumber,"Option A"],"OB":questionare.loc[eachRandomNumber,"Option B"],"OC":questionare.loc[eachRandomNumber,"Option C"],"OD":questionare.loc[eachRandomNumber,"Option D"],"RA":questionare.loc[eachRandomNumber,"Right Answer"]}
    questionList.append(singleQuestion)

print(questionList)
# Out:
# [{'Question': 'Which year did the Titanic sink?', 'OA': '1905', 'OB': '1912', 'OC': '1918', 'OD': '1924', 'RA': 'B'}, {'Question': 'What is the value of Pi rounded to two decimal places?', 'OA': '3.12', 'OB': '3.14', 'OC': '3.16', 'OD': '3.18', 'RA': 'B'}, {'Question': 'What is the currency of the United Kingdom?', 'OA': 'Euro', 'OB': 'Dollar', 'OC': 'Pound Sterling', 'OD': 'Yen', 'RA': 'C'}, {'Question': "Which data structure follows the 'Last-In, First-Out' (LIFO) principle?", 'OA': 'Queue', 'OB': 'Array', 'OC': 'Stack', 'OD': 'Linked List', 'RA': 'C'}, {'Question': 'What is the capital city of Japan?', 'OA': 'Seoul', 'OB': 'Beijing', 'OC': 'Bangkok', 'OD': 'Tokyo', 'RA': 'D'}, {'Question': 'Which component is responsible for long-term data storage?', 'OA': 'RAM', 'OB': 'CPU', 'OC': 'HDD/SSD', 'OD': 'GPU', 'RA': 'C'}, {'Question': 'Who painted the Mona Lisa?', 'OA': 'Vincent van Gogh', 'OB': 'Pablo Picasso', 'OC': 'Leonardo da Vinci', 'OD': 'Claude Monet', 'RA': 'C'}, {'Question': 
# ...

# %%
while True:
    choice = input ("Enter 1 to take the quiz or 2 to exit:")

    if choice  ==  1:
        studentName = input("Enter Your Name:")
        studentScoreSheet= pd.read_csv("StudentScore.csv")
        studentScore = 0
        if studentName in list(studentScoreSheet["Names"]):
            print("You have already taken the quiz")
            continue
        else:
            studentList = [studentName]
            print("User Registered Starting the quiz")
            for question in questionList:
                print(question["Question"])
                print(f"A. {question['OA']}")
                print(f"B. {question['OB']}")
                print(f"C. {question['OC']}")
                print(f"D. {question['OD']}")
                userAnswer = input("Enter Your Answer:")
                if userAnswer == question["RA"]:
                    print("Correct Answer")
                    studentScore = studentScore + 1
                else:
                    print("Wrong Answer")
                    print(f"Correct Answer is {question['RA']}")
                    break




    elif choice == 2:
        print("Quiz Ended")
        break
# Out:
# What is the value of Pi rounded to two decimal places?

# %%
import pandas as pd

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems[["Description","Secondary Description"]]
# Out:
#                                              Description  \
# 0      زيت مغذي للشفاه, يُعزز لمعان الشفاه بتأثير بصر...
# 1      عطر أروماتك إنيق للرجال.\nمكونات العطر: العنبر...
# 2      سيروم خفيف الوزن وغير دهني يعالج تساقط الشعر و...
# 3      عطر شرقي حار للجنسين.\nمقدمة العطر: البخور, ال...
# 4      امنحي حواجبك شكلاً أنيقًا يدوم طوال اليوم مع ج...
# ...                                                  ...
# 24697  زذاذ معطر الجسم والشعر منعش وفواح, يتكون من مز...
# 24698  رذاذ معطر الجسم والشعر جذاب ومنعش للنساء, يمتا...
# 24699  ماسكارا تتميز بفرشاتها ذات الشعيرات الكثيفة, ت...
# 24700  رذاذ معطر للجسم, يساعدك على الشعور بالانتعاش و...
# 24701  ماسكارا تتميز بفرشاتها ذات الشعيرات الكثيفة, ت...
#
#                                    Secondary Description
# 0      Nourishing lip oil that enhances lip shine wit...
# 1      An elegant aromatic fragrance for men.\nFragra...
# 2      A lightweight, non greasy serum that treats ha...
# ...

# %%
set(dfItems["Secondary Brand"])
# Out:
# {'4 Long Lashes',
#  '7DAYS',
#  'AL haramain',
#  'Abdul Samad Al Qurashi',
#  'Acqua Di Parisis',
#  'Acqua Di Parma',
#  'Agatho Perfume',
#  'Agent Provocateur',
#  'Al Tahara Musk',
#  'Al Tahara Royal Muck',
#  'Alba Botanica',
#  'Albane Noble',
#  'Alexandre.J',
#  'Alfaparf Milano',
#  'Almorel',
#  'Alterna',
#  'Amara Lenses',
#  'Ameera London',
#  'Amouage',
#  'Anastasia Beverly Hills',
#  'Andrea',
#  'Anesthesia',
#  'Anfas',
#  'Angel Barlen',
#  'Angel En Provence',
#  'Angel Schlesser',
#  'Annick Goutal',
#  'Answr',
#  'Antonio Croce Perfumes',
#  'Anua',
#  'Aquafresh',
#  'Aquarelle Paris',
#  'Aquarely',
#  'Aramis',
#  'Arcancil',
#  'Ardell',
#  'Argan Deluxe',
#  'Arm & Hammer',
#  'Armaf',
#  'ArtNaturals',
#  'Artdeco',
#  'Ascada Beauty',
#  'Aspel',
#  'Assaf',
#  'Ateej',
#  'Atelier Des Ors',
#  'Atelier Flou',
#  'Atelier Versace',
#  'Atyab Al Marshoud',
#  'Aussie',
#  'Avène',
#  'Awshal Perfumes',
#  'Axe',
#  'Axis-y',
#  'Aya',
#  'Ayten',
# ...

# %%
dfItems[dfItems["Secondary Brand"]=="Nivea"]
# Out:
#                                                  Picture      Id  \
# 15                                                   NaN  390143
# 809    https://www.storeakmedia.com/storeak-erp/Store...  359629
# 810    https://www.storeakmedia.com/storeak-erp/Store...  359628
# 814    https://www.storeakmedia.com/storeak-erp/Store...  359607
# 815    https://www.storeakmedia.com/storeak-erp/Store...  359606
# ...                                                  ...     ...
# 22999  https://www.storeakmedia.com/storeak-erp/Store...  316752
# 23063  https://www.storeakmedia.com/storeak-erp/Store...  316688
# 23064  https://www.storeakmedia.com/storeak-erp/Store...  316687
# 23065  https://www.storeakmedia.com/storeak-erp/Store...  316686
# 23066  https://www.storeakmedia.com/storeak-erp/Store...  316685
#
#                                                     Name  \
# 15            جل استحمام بزيت جوز الهند والجوجوبا 750 مل
# 809    بلسم ما بعد الحلاقة للبشرة الحساسة برو ألترا ك...
# ...

# %%
MessyPrice =  list(dfItems["Price"])
CleanedPrice = []
for price in MessyPrice:
   price = price.replace("د.ع","")
   price = price.replace(",","")
   CleanedPrice.append(int(price))
dfItems["Price"]=CleanedPrice

# %%
CleanedPrice
# Out:
# [25000,
#  300000,
#  30000,
#  0,
#  15000,
#  15000,
#  18000,
#  15000,
#  7750,
#  15500,
#  65000,
#  3500,
#  19000,
#  38000,
#  15500,
#  8000,
#  115500,
#  6500,
#  30000,
#  20000,
#  4000,
#  30000,
#  4000,
#  32000,
#  4000,
#  30000,
#  45000,
#  37000,
#  30000,
#  10000,
#  3500,
#  3500,
#  45000,
#  45000,
#  15000,
#  50000,
#  7500,
#  120000,
#  15000,
#  5000,
#  120000,
#  5000,
#  4500,
#  5000,
#  75000,
#  13000,
#  75000,
#  6500,
#  19000,
#  6500,
#  6500,
#  6500,
#  28000,
#  5000,
#  5000,
#  8500,
#  5000,
#  5000,
#  17000,
#  15000,
#  19750,
#  19750,
#  27000,
#  27000,
#  30000,
#  30500,
#  23000,
#  9000,
#  25000,
#  9000,
#  25000,
#  32000,
#  16000,
#  9000,
#  27000,
#  9000,
#  27000,
#  370000,
#  10500,
#  10500,
#  37500,
#  60000,
#  7000,
#  120000,
#  18500,
#  25000,
#  39000,
#  22000,
#  19000,
#  163250,
#  255250,
#  72000,
#  45000,
#  124250,
#  28750,
#  109250,
#  26250,
#  26250,
#  71000,
#  92500,
#  18250,
#  92500,
# ...

# %%
dfItems["Price"]=CleanedPrice

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems[(dfItems["Secondary Brand"]=="Nivea") & (dfItems["Price"]>1000)]
# Out:
#                                                  Picture      Id  \
# 15                                                   NaN  390143
# 809    https://www.storeakmedia.com/storeak-erp/Store...  359629
# 810    https://www.storeakmedia.com/storeak-erp/Store...  359628
# 814    https://www.storeakmedia.com/storeak-erp/Store...  359607
# 815    https://www.storeakmedia.com/storeak-erp/Store...  359606
# ...                                                  ...     ...
# 22999  https://www.storeakmedia.com/storeak-erp/Store...  316752
# 23063  https://www.storeakmedia.com/storeak-erp/Store...  316688
# 23064  https://www.storeakmedia.com/storeak-erp/Store...  316687
# 23065  https://www.storeakmedia.com/storeak-erp/Store...  316686
# 23066  https://www.storeakmedia.com/storeak-erp/Store...  316685
#
#                                                     Name  \
# 15            جل استحمام بزيت جوز الهند والجوجوبا 750 مل
# 809    بلسم ما بعد الحلاقة للبشرة الحساسة برو ألترا ك...
# ...

# %%
dfItems.loc[dfItems["Id"]==359629,"Price"]=15000

# %%
dfItems[dfItems["Id"]==359629]
# Out:
#                                                Picture      Id  \
# 809  https://www.storeakmedia.com/storeak-erp/Store...  359629
#
#                                                   Name  \
# 809  بلسم ما بعد الحلاقة للبشرة الحساسة برو ألترا ك...
#
#                                         Secondary Name        Barcode Code  \
# 809  After Shave Balm Sensitive Pro Ultra Calming 1...  9005800347479    0
#
#      Price                                        Description  \
# 809  15000  بلسم مهدئ البشرة ما بعد الحلاقة، تحتوي تركيبته...
#
#                                  Secondary Description  \
# 809  This soothing aftershave balm, formulated with...
#
#                                        Sub Description  \
# 809  |نيفيا|Nivea|العناية بالرجال بعد الحلاقة|Men C...
#
#     Secondary Sub Description                                        Menu  \
# 809                       NaN  العناية بالرجال‎ -> اللحية‎ -> بعد الحلاقة
#
#      Brand Secondary Brand Has Collections
# ...

# %%
dfItems[["Secondary Name", "Price"]]
# Out:
#                                           Secondary Name   Price
# 0                             Pleasure Lip Oil 001, 5 ml   25000
# 1                       Bleu De Chanel L'Exclusif Parfum  300000
# 2                        Seapuri Scalpy Hair Serum 20 ml   30000
# 3                                     Ganymede EDP 50 ml       0
# 4                  Brow Styling Gel With Peptides 15 ml    15000
# ...                                                  ...     ...
# 24697              Lime & Matcha Hair & Body Mist 150 ml   16500
# 24698       Pink Pepper & Lychee Hair & Body Mist 150 ml   12000
# 24699  Glam & Doll Boost Lash Growth Volume Mascara 8 ml   10500
# 24700                      Body Mist Passion Fruit150 ml   15000
# 24701              Volume Supreme Mascara (1Black) 15 ml   22500
#
# [24702 rows x 2 columns]

# %%
dfItems["New Secondary Name"] = dfItems["Secondary Name"].str.cat(dfItems['Price'].astype(str),sep="")

# %%
dfItems[["Secondary Name","New Secondary Name"]]
# Out:
#                                           Secondary Name  \
# 0                             Pleasure Lip Oil 001, 5 ml
# 1                       Bleu De Chanel L'Exclusif Parfum
# 2                        Seapuri Scalpy Hair Serum 20 ml
# 3                                     Ganymede EDP 50 ml
# 4                  Brow Styling Gel With Peptides 15 ml
# ...                                                  ...
# 24697              Lime & Matcha Hair & Body Mist 150 ml
# 24698       Pink Pepper & Lychee Hair & Body Mist 150 ml
# 24699  Glam & Doll Boost Lash Growth Volume Mascara 8 ml
# 24700                      Body Mist Passion Fruit150 ml
# 24701              Volume Supreme Mascara (1Black) 15 ml
#
#                                       New Secondary Name
# 0                        Pleasure Lip Oil 001, 5 ml25000
# 1                 Bleu De Chanel L'Exclusif Parfum300000
# 2                   Seapuri Scalpy Hair Serum 20 ml30000
# ...

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems.drop(columns=["Sub Description","Secondary Sub Description"],inplace=True)

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems.rename(columns={"English Name":"English Names","Name":"Arabic Names"},inplace=True)

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                            Arabic Names  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfCollections
# Drop columns size, Unit level
# Clean Price column
# Concatenate Item name with color & Secondary Item Name with Secondary Color
# Assign to the same columns
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name Color Code       Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420,000د.ع
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300,000د.ع
# 2                              The Glow Stick    #F3D5C6   19,750د.ع
# ...

# %%
dfCollections.drop(columns=["Size","Unit Level"],inplace=True)

# %%
dfCollections
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name Color Code       Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420,000د.ع
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300,000د.ع
# 2                              The Glow Stick    #F3D5C6   19,750د.ع
# ...

# %%
MessyPrice =  list(dfCollections["Price"])
CleanedPrice = []
for price in MessyPrice:
   price = price.replace("د.ع","")
   price = price.replace(",","")
   CleanedPrice.append(int(price))
dfCollections["Price"]=CleanedPrice

# %%
dfCollections
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name Color Code   Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420000
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300000
# 2                              The Glow Stick    #F3D5C6   19750
# ...

# %%
dfCollections["Item Name"] = dfCollections["Item Name"].str.cat(dfCollections['Color'].astype(str),sep="")

# %%
dfCollections
# Out:
#        Item Id                                    Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد50 مل
# 2       364804                 هايلايتر ستك24 سباركلينج بيج
# 3       364804                      هايلايتر ستك25 روز جليم
# 4       364793                                 كونتور ستك30
# ...        ...                                          ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف88.7 مل
#
#                           Secondary Item Name Color Code   Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420000
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300000
# ...

# %%
dfCollections["Secondary Item Name"] = dfCollections["Secondary Item Name"].str.cat(dfCollections['Secondary Color'].astype(str),sep="")

# %%
dfCollections
# Out:
#        Item Id                                    Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد50 مل
# 2       364804                 هايلايتر ستك24 سباركلينج بيج
# 3       364804                      هايلايتر ستك25 روز جليم
# 4       364793                                 كونتور ستك30
# ...        ...                                          ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف88.7 مل
#
#                                  Secondary Item Name Color Code   Price  \
# 0             Bleu De Chanel L'Exclusif Parfum100 ml        NaN  420000
# 1              Bleu De Chanel L'Exclusif Parfum50 ml        NaN  300000
# ...

# %%
dfCollections.drop(columns=["Color","Secondary Color"],inplace=True)

# %%
dfCollections
# Out:
#        Item Id                                    Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد50 مل
# 2       364804                 هايلايتر ستك24 سباركلينج بيج
# 3       364804                      هايلايتر ستك25 روز جليم
# 4       364793                                 كونتور ستك30
# ...        ...                                          ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف88.7 مل
#
#                                  Secondary Item Name Color Code   Price  \
# 0             Bleu De Chanel L'Exclusif Parfum100 ml        NaN  420000
# 1              Bleu De Chanel L'Exclusif Parfum50 ml        NaN  300000
# ...

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                            Arabic Names  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
# Drop Sub Description and Secondary Sub description
# price Clean
# Filter that how many items has Collections as true

# %%
dfItems.drop(columns=["Sub Description","Secondary Sub Description"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 dfItems.drop(columns=["Sub Description","Secondary Sub Description"],inplace=True)
#
# File C:\CurrentUnityProjects\NavClassAdvancePython\AdvancePythonClassRepo\.venv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
# ...

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                            Arabic Names  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
MessyPrice =  list(dfItems["Price"])
CleanedPrice = []
for price in MessyPrice:
   price = price.replace("د.ع","")
   price = price.replace(",","")
   CleanedPrice.append(int(price))
dfItems["Price"]=CleanedPrice

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                            Arabic Names  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems[dfItems["Has Collections"]=="Yes"]
# Out:
#                                                  Picture      Id  \
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 60     https://www.storeakmedia.com/storeak-erp/Store...  364804
# 61     https://www.storeakmedia.com/storeak-erp/Store...  364793
# 94     https://www.storeakmedia.com/storeak-erp/Store...  364529
# 107    https://www.storeakmedia.com/storeak-erp/Store...  364479
# ...                                                  ...     ...
# 8252   https://www.storeakmedia.com/storeak-erp/Store...  332030
# 8253   https://www.storeakmedia.com/storeak-erp/Store...  332028
# 8254   https://www.storeakmedia.com/storeak-erp/Store...  332027
# 23139  https://www.storeakmedia.com/storeak-erp/Store...  316612
# 23141  https://www.storeakmedia.com/storeak-erp/Store...  316610
#
#                                             Arabic Names  \
# 1                   عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 60                                          هايلايتر ستك
# ...

# %%
dfCollections
# Out:
#        Item Id                                    Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد50 مل
# 2       364804                 هايلايتر ستك24 سباركلينج بيج
# 3       364804                      هايلايتر ستك25 روز جليم
# 4       364793                                 كونتور ستك30
# ...        ...                                          ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف88.7 مل
#
#                                  Secondary Item Name Color Code   Price  \
# 0             Bleu De Chanel L'Exclusif Parfum100 ml        NaN  420000
# 1              Bleu De Chanel L'Exclusif Parfum50 ml        NaN  300000
# ...

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                            Arabic Names  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
# check by comparing id from boths sheets and see if all the products from
#Collections sheet exist in items sheet

# %%
# Merge both sheets
# Compare both ids = On id's getting matched retrieve the information
# For the specific product Id, Name , Secondary Name , barcode , price from collection
# for same product you can get description , secondary Description, Menu , Brand and Secondary brand from items sheet
# Attach new row at the end of items sheet

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                            Arabic Names  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfCollections
# Out:
#        Item Id                                    Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد50 مل
# 2       364804                 هايلايتر ستك24 سباركلينج بيج
# 3       364804                      هايلايتر ستك25 روز جليم
# 4       364793                                 كونتور ستك30
# ...        ...                                          ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف88.7 مل
#
#                                  Secondary Item Name Color Code   Price  \
# 0             Bleu De Chanel L'Exclusif Parfum100 ml        NaN  420000
# 1              Bleu De Chanel L'Exclusif Parfum50 ml        NaN  300000
# ...

# %%
CollectoinSheetIds = dfCollections["Item Id"]

# %%
CollectoinSheetIds
# Out:
# 0        390187
# 1        390187
# 2        364804
# 3        364804
# 4        364793
#           ...
# 14481    332027
# 14482    316612
# 14483    316612
# 14484    316610
# 14485    316610
# Name: Item Id, Length: 14486, dtype: int64

# %%
ItemSheetIds =  dfItems["Id"].tolist()

# %%
ItemSheetIds
for eachId in CollectoinSheetIds:
    if eachId in ItemSheetIds:
        picture  = dfCollections.loc[dfCollections["Item Id"]==eachId,"Picture"]
        Barcode  = dfCollections.loc[dfCollections["Item Id"]==eachId,"Barcode"]
        Item_Name  = dfCollections.loc[dfCollections["Item Id"]==eachId,"Item Name"]
        Secondary_Item_Name  = dfCollections.loc[dfCollections["Item Id"]==eachId,"Secondary Item Name"]
        Price  = dfCollections.loc[dfCollections["Item Id"]==eachId,"Price"]

        Description  = dfItems.loc[dfItems["Id"]==eachId,"Description"]
        Secondary_Description  = dfItems.loc[dfItems["Id"]==eachId,"Secondary Description"]
        Menu  = dfItems.loc[dfItems["Id"]==eachId,"Menu"]
        Brand  = dfItems.loc[dfItems["Id"]==eachId,"Brand"]
        Secondary_Brand  = dfItems.loc[dfItems["Id"]==eachId,"Secondary Brand"]
        currentrowNumber = len(dfItems["Id"])
        dfItems.loc[currentrowNumber] = [picture,eachId,Item_Name,Secondary_Item_Name,Barcode,"NAN",Price,Description,Secondary_Description,Menu,Brand,Secondary_Brand,False]
        print("Matched"+" "+str(eachId)+" "+str(currentrowNumber))

    else:
        print("Not Matched")
# Out:
# Matched 390187 24702
# Matched 390187 24703
# Matched 364804 24704
# Matched 364804 24705
# Matched 364793 24706
# Matched 364793 24707
# Matched 364793 24708
# Matched 364793 24709
# Matched 364529 24710
# Matched 364529 24711
# Matched 364529 24712
# Matched 364479 24713
# Matched 364479 24714
# Matched 364479 24715
# Matched 364030 24716
# Matched 364030 24717
# Matched 364030 24718
# Matched 364030 24719
# Matched 363953 24720
# Matched 363953 24721
# Matched 363951 24722
# Matched 363951 24723
# Matched 363949 24724
# Matched 363949 24725
# Matched 363948 24726
# Matched 363948 24727
# Matched 363946 24728
# Matched 363946 24729
# Matched 363523 24730
# Matched 363523 24731
# Matched 363523 24732
# Matched 363523 24733
# Matched 363147 24734
# Matched 363147 24735
# Matched 363104 24736
# Matched 363104 24737
# Matched 362740 24738
# Matched 362740 24739
# Matched 362705 24740
# Matched 362705 24741
# Matched 362294 24742
# Matched 362294 24743
# Matched 362293 24744
# ...

# %%
dfItems
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 39183  14476    https://www.storeakmedia.com/storeak-...  332027
# 39184  14482    https://www.storeakmedia.com/storeak-...  316612
# 39185  14482    https://www.storeakmedia.com/storeak-...  316612
# 39186  14484                                         ...  316610
# 39187  14484                                         ...  316610
#
#                                             Arabic Names  \
# 0                             زيت الشفاه بليجر 001، 5 مل
# 1                   عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
dfItems.to_csv("FinalItems.csv",index=False)
