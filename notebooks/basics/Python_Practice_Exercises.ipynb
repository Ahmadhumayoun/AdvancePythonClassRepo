# %% [raw]
# """
# Task: Create a script that asks for a user's name and birth year.
#
# Requirements:
#
# Calculate their age (assume the current year is 2026).
#
# Use a string method to ensure their name is properly capitalized (e.g., "bob" becomes "Bob").
#
# Print a message like: "Hello [Name], you are [Age] years old!"
#
# Use an if statement to print an extra message if they are over 18.
# """

# %%
from cffi.cffi_opcode import PRIM_INT

userName = input("Enter your name: ")
birthYear = int(input('Enter your age:'))
currentYear = 2026
captilizedName = userName.capitalize()
PersonAge = currentYear - birthYear
if PersonAge >=18:
    print(f"Hello {captilizedName}, you are {PersonAge} years old and are over 18 years old")
else:
    print(f"Hello {captilizedName}, you are {PersonAge} years old!")
# Out:
# Hello Ahmad, you are 26 years old and are over 18 years old

# %%
priceList = ["100rs","15rs","20rs","30rs","25rs","45rs","95rs","1010rs","50rs","5rs","7rs",'9rs']
expensivePrices = []
cheapPrices = []

for p in priceList:
    if p > 50:
        expensivePrices.append(p)
    else:
        cheapPrices.append(p)
print(expensivePrices)
print(cheapPrices)
# Out:
# [100, 95, 1010]
# [15, 20, 30, 25, 45, 50, 5, 7, 9]

# %%
priceList = ["100rs","15rs","20rs","30rs","25rs","45rs","95rs","1010rs","50rs","5rs","7rs",'9rs']
expensivePrices = []
cheapPrices = []
for p in priceList:
    # print(p)
    cleanedPrice = int(p.replace("rs",""))
    if cleanedPrice > 50:
        expensivePrices.append(p)
    else:
        cheapPrices.append(p)

# %%
print(expensivePrices)
print(cheapPrices)
# Out:
# ['100rs', '95rs', '1010rs']
# ['15rs', '20rs', '30rs', '25rs', '45rs', '50rs', '5rs', '7rs', '9rs']

# %%
# length Should be atleast 8 characters
# Shouldn't be any spaces in there
# Check if there is atleast 1 number

# %%
passwd = input("Enter the password : ")
if len(passwd)<8:
    print("Password should be atleast 8 characters")
if " " in passwd:
    print("Password shouldn't contain spaces")
HasNumber = False
for Char in passwd:
    if Char.isdigit():
        HasNumber = True
        break
    else:
        pass

if HasNumber == True:
    print("Password is Valid")
else:
    print("There should be atleast 1 number in the password")

# %%
plist = [50,100,120,150,200,400,450,475,500,700,1000]
twentyPerCentDiscountList= [] # Price Above 200 , Will be applied 20% discount and append to this list
ten_Twenty = [] # Price between 100-200 , Will be applied 10% discount and append to this list
UnerTen = [] # under 100 , No discount and append to this list

# %%
ProductList = ["Biscuits","Chips","Meat","Eggs","Bread"]
PriceList = ["20rs","50rs","500rs","300rs","100rs"]
cart = []
totalPrice = 0

# %%
while True:
    print("Enter 1 for Biscuits\n Enter 2 for Chips\n Enter 3 for Meat\n Enter 4 for Eggs\n Enter 5 for Bread")
    choice = input("")
    print(f"How much do you want to buy?")
    quantity = int(input(""))
    if choice == "1":
        for i in range(quantity):
            cart.append(ProductList[0])
            totalPrice = totalPrice + int(PriceList[0].replace("rs",""))
    elif choice == "2":
        for i in range(quantity):
            cart.append(ProductList[1])
            totalPrice = totalPrice + int(PriceList[1].replace("rs",""))
    elif choice == "3":
        for i in range(quantity):
            cart.append(ProductList[2])
            totalPrice = totalPrice + int(PriceList[2].replace("rs",""))
    elif  choice == "4":
        for i in range(quantity):
            cart.append(ProductList[3])
            totalPrice = totalPrice + int(PriceList[3].replace("rs",""))
    elif choice == "5":
        for i in range(quantity):
            cart.append(ProductList[4])
            totalPrice = totalPrice + int(PriceList[4].replace("rs",""))
    print("Do you want to shop more?y/n")
    answer = input("")
    if answer == "n":
        break
    else:
        continue
# Out:
# Enter 1 for Biscuits
#  Enter 2 for Chips
#  Enter 3 for Meat
#  Enter 4 for Eggs
#  Enter 5 for Bread
# How much do you want to buy?
# Do you want to shop more?y/n
# Enter 1 for Biscuits
#  Enter 2 for Chips
#  Enter 3 for Meat
#  Enter 4 for Eggs
#  Enter 5 for Bread
# How much do you want to buy?
# Do you want to shop more?y/n

# %%
print(cart)
print(totalPrice)
# Out:
# ['Biscuits', 'Biscuits', 'Chips', 'Chips', 'Chips', 'Chips', 'Chips', 'Eggs', 'Eggs', 'Eggs', 'Eggs', 'Eggs']
# 1790

# %%
import random

# %%
print(random.randint(0,3))
# Out:
# 0

# %%
li = ["rock","paper","sci"]

# %%
computerChoice = random.choice(li)

# %%
userChoice = input("Choose rock, paper or sci")
if userChoice.lower() == "rock" and computerChoice == "paper" or userChoice.lower() == "paper" and computerChoice == "sci" or userChoice.lower() == "sci" and computerChoice == "rock":
    print("You Loose")
else:
    print("you won")
# Out:
# 'paper'

# %%
import numpy
import pandas
