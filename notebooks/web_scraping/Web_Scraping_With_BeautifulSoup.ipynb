# %%
from tqdm import tqdm
import pandas as pd
import requests as r
from bs4 import BeautifulSoup as bs

# %%
cardsUrl ="https://www.deckshop.pro/card/list"
response =r.get(cardsUrl)

# %%
with open("CardsUrl.html","w") as file:
    file.write(response.text)

# %%
baseUrl = "https://www.deckshop.pro"
with open ("CardsUrl.html","r") as file:
    sourceCode = file.read()
    soup = bs(sourceCode, "html.parser")
    cardsUrls = soup.find_all("img",{"class":"card"})
    cardDictioanry = {"Cards Name":[],"Cards Image Urls": []}
    for eachUrl in tqdm( cardsUrls,desc="Downloading Cards",unit="img"):
        cardDictioanry["Cards Name"].append( eachUrl.get("src").split("/")[-1].split(".")[0])
        cardDictioanry["Cards Image Urls"].append(eachUrl.get("src"))
        # tqdm.write(f"Downloading {eachUrl.get('src').split('/')[-1]}...")
        downloadedImage = r.get(baseUrl+eachUrl.get("src"))
        with open("CardsDownload/"+eachUrl.get("src").split("/")[-1],"wb") as img:

            img.write(downloadedImage.content)
    cardDataFrame = pd.DataFrame(cardDictioanry)
    cardDataFrame
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 11
#       9 cardDictioanry["Cards Image Urls"].append(eachUrl.get("src"))
#      10 # tqdm.write(f"Downloading {eachUrl.get('src').split('/')[-1]}...")
# ---> 11 downloadedImage = r.get(baseUrl+eachUrl.get("src"))
#      12 with open("CardsDownload/"+eachUrl.get("src").split("/")[-1],"wb") as img:
#      14     img.write(downloadedImage.content)
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
cardDataFrame
# Out:
#       Cards Name                Cards Image Urls
# 0       Skellies   /img/card_ed_evo/Skellies.png
# 1      IceSpirit  /img/card_ed_evo/IceSpirit.png
# 2         Bomber     /img/card_ed_evo/Bomber.png
# 3           Bats       /img/card_ed_evo/Bats.png
# 4            Zap        /img/card_ed_evo/Zap.png
# ..           ...                             ...
# 524  MightyMiner    /img/card_ed/MightyMiner.png
# 525  ArcherQueen    /img/card_ed/ArcherQueen.png
# 526  Goblinstein    /img/card_ed/Goblinstein.png
# 527         Monk           /img/card_ed/Monk.png
# 528   BossBandit     /img/card_ed/BossBandit.png
#
# [529 rows x 2 columns]

# %%
response = r.get("https://fake-json-api.mock.beeceptor.com/users")
print(response.text)
# Out:
# [
#   {
#     "id": 1,
#     "name": "Clemmie Hansen",
#     "company": "McGlynn LLC",
#     "username": "Era40",
#     "email": "Alfonzo_Barton-Buckridge@hotmail.com",
#     "address": "16365 Gislason Shoals",
#     "zip": "14811-1784",
#     "state": "Nebraska",
#     "country": "Heard Island and McDonald Islands",
#     "phone": "489-381-9235 x839",
#     "photo": "https://json-server.dev/ai-profiles/64.png"
#   },
#   {
#     "id": 2,
#     "name": "Thora Faker Attribute Error: person.astName is not supported",
#     "company": "Crona, Emard and Batz",
#     "username": "Estefania26",
#     "email": "Telly73@gmail.com",
#     "address": "145 Talon Ranch",
#     "zip": "63332-8895",
#     "state": "South Dakota",
#     "country": "Portugal",
#     "phone": "750-878-6183 x6323",
#     "photo": "https://json-server.dev/ai-profiles/19.png"
#   },
#   {
#     "id": 3,
#     "name": "Jarred McClure",
#     "company": "Bartell - Barrows",
#     "username": "Cordia.Hamill3",
# ...

# %%
tableresponse = r.get("https://www.scrapethissite.com/pages/forms/")
with open("TableData.html","w") as file:
    file.write(tableresponse.text)

# %%
with open("TableData.html","r") as file:
    sourceCode = file.read()
    soup = bs(sourceCode,"html.parser")
    tableData = soup.find_all("tr")
    tableDataList = []
    for eachRow in tableData:
        cell = eachRow.find_all(["td","th"])
        singleRow=[]
        for eachCell in cell:
            singleRow.append(eachCell.get_text().strip())
        tableDataList.append(singleRow)

# %%
tableDF = pd.DataFrame(tableDataList[1:],columns=tableDataList[0])

# %%
tableDF
# Out:
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0           Boston Bruins  1990   44     24             0.55            299
# 1          Buffalo Sabres  1990   31     30            0.388            292
# 2          Calgary Flames  1990   46     26            0.575            344
# 3      Chicago Blackhawks  1990   49     23            0.613            284
# 4       Detroit Red Wings  1990   34     38            0.425            273
# 5         Edmonton Oilers  1990   37     37            0.463            272
# 6        Hartford Whalers  1990   31     38            0.388            238
# 7       Los Angeles Kings  1990   46     24            0.575            340
# 8   Minnesota North Stars  1990   27     39            0.338            256
# 9      Montreal Canadiens  1990   39     30            0.487            273
# 10      New Jersey Devils  1990   32     33              0.4            272
# ...
