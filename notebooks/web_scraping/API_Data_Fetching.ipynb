# %%
import pandas as pd
import requests as r
# Out:
# /Users/muhammadahmadhumayoun/PyCharmMiscProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
response = r.get("https://fake-json-api.mock.beeceptor.com/users")

# %%
# print(response.json())
userResponse = response.json()
userDatadf = pd.DataFrame(userResponse)

# %%
userDatadf
# Out:
#    id                                               name  \
# 0   1                                        Alex Waters
# 1   2  Michael Faker Attribute Error: person.astName ...
# 2   3                                     Reginald Hauck
# 3   4                                       Jonatan Rowe
# 4   5                               August Hyatt-Abshire
# 5   6                                      Harley Jacobs
# 6   7                              Casandra Schultz-Hand
# 7   8                                            Fay Fay
# 8   9                                         Clara Hane
# 9  10                              Dannie Watsica-Crooks
#
#                          company                        username  \
# 0                 Kihn - Stroman                          Zora97
# 1                    Leffler Inc                       Montana86
# 2                    Metz - Batz               Amir_Grady-Raynor
# 3                    Ebert Group                        Lauryn16
# ...

# %%
url = 'https://api.escuelajs.co/api/v1/auth/login'
h = {
    'Content-Type': 'application/json'
}
accesToken = ""
credentials = {"email":"john@mail.com","password":"changeme"}
response = r.post(url,json = credentials,headers=h)
print(response.json())
postresponse = response.json()
accessToken = postresponse['access_token']
print(accessToken)
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ5MTA4NiwiZXhwIjoxNzc3MjE5MDg2fQ.3W98TY1lUDqn8GD1EaOBr5ekLM9-TL6jJR_xrRb3IZs', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ5MTA4NiwiZXhwIjoxNzc1NTI3MDg2fQ.oBOZB3phaCalFNGoXgaUvTDeeOQ0BW-WFWNnPMa8DDQ'}
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ5MTA4NiwiZXhwIjoxNzc3MjE5MDg2fQ.3W98TY1lUDqn8GD1EaOBr5ekLM9-TL6jJR_xrRb3IZs

# %%
userProfileUrl = "https://api.escuelajs.co/api/v1/auth/profile"
newheader = {
    "Authorization": f"Bearer {accessToken}"
}

# %%
profielResponse = r.get(userProfileUrl,headers=newheader)
print(profielResponse.json())
# Out:
# {'id': 1, 'email': 'john@mail.com', 'password': 'changeme', 'name': 'Jhon', 'role': 'customer', 'avatar': 'https://i.imgur.com/LDOO4Qs.jpg', 'creationAt': '2026-04-06T03:15:21.000Z', 'updatedAt': '2026-04-06T03:15:21.000Z'}

# %%
imageUrlResponse = r.get("https://i.imgur.com/LDOO4Qs.jpeg")
with open("avatar.jpeg","wb") as img:
    img.write(imageUrlResponse.content)
