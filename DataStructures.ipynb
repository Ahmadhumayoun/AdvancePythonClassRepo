# %%
#List
#Tuple
#Set _ Least Usecase
#Dictionary

# %%
li = ["ahmad",True,10,4.5]

# %%
print(type(li))
print(li[0][2])
print(type(li[0]))
# Out:
# <class 'list'>
# m
# <class 'str'>

# %%
li = [2,"Ahmad",3.5,"Python"]
print(f" Addtion is {li[0]+li[2]}")
print(f" Concatination is {li[1] + li[3]}")
# Out:
#  Addtion is 5.5
#  Concatination is AhmadPython

# %%
li = ["100","9","Python Class","n","a"]

# %%
print(f"Division Solution is {int(int(li[0])/int(li[1]))}")
# Out:
# Division Solution is 11

# %%
print("===replacement===")
replacePhrase = li[2].replace(li[3],li[4])
print(replacePhrase)
# Out:
# ===replacement===
# Pythoa Class

# %%
li = ["100","9","Python Class","n","a"]
sepratedStr=  li[2]

# %%
sepratedStr.replace(li[-2],li[-1])
# Out:
# 'Pythoa Class'

# %%
li1 = [1,2,3,["A","B",4],"C"]

# %%
print(f"addition is {li1[0]+li1[1]+li1[2]+li1[3][-1]}")
# Out:
# addition is 10

# %%
print(f"Concatination is{li1[3][0]+li1[3][1]+li1[-1]}")
# Out:
# Concatination isABC

# %%
li1.append("Ahmad")

# %%
li1
# Out:
# [1, 2, 3, ['A', 'B', 4], 'C', 'Ahmad']

# %%
li1.insert(0,"Ahmad2")

# %%
li1.remove("Ahmad2")

# %%
li1
# Out:
# [1, 2, 3, ['A', 'B', 4], 'C', 'Ahmad']

# %%
li2 = [4,5,1,2]

# %%
li2.sort()

# %%
print(li2)
# Out:
# [1, 2, 4, 5]

# %%
t = (1,2,3,4,5,6)
t.append("Ahmad")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 2
#       1 t = (1,2,3,4,5,6)
# ----> 2 t.append("Ahmad")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
li = [6,6,8,1,2,2,4]
tpl = (6,6,8,1,2,2,4)
st = {6,6,8,1,2,2,4}

# %%
print(f"list is {li}")
print(f"Tuple is {tpl}")
print(f"Set is {st}")
# Out:
# list is [6, 6, 8, 1, 2, 2, 4]
# Tuple is (6, 6, 8, 1, 2, 2, 4)
# Set is {1, 2, 4, 6, 8}

# %%
li = (1,2,3,4,5,6)
# list =[]
# tuple = ()
# set ={}
for value in li:
    print(value*2)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %%
li = [1,2,3,[3,4,5,["Ahmad","Python"]]]
print(li[3][3][1])
# Out:
# Python

# %%
priceList = ["100,000","200,000","300,000"]
for SingplePrice in priceList:
    newPrice = SingplePrice.replace(",","")
    print(int(newPrice))

for eachElement in range(0,len(priceList)):
    # print(priceList[eachElement])
    newprice = priceList[eachElement].replace(",","")
    print(int(newprice))
# Out:
# 100000
# 200000
# 300000
# 100000
# 200000
# 300000

# %%
priceList = ["100,000","200,000","300,000"]
for SingplePrice in priceList:
    newPrice = SingplePrice.replace(",","")
    print(int(newPrice))

for eachElement in range(0,len(priceList)):
    # print(priceList[eachElement])
    newprice = priceList[eachElement].replace(",","")
    print(int(newprice))
#---------------------------
li = ["Ahmad","2","7","python"]
# Out:
# 100000
# 200000
# 300000
# 100000
# 200000
# 300000

# %%
li = ["Ahmad","2","7","python"]

for element in li :
    if isinstance(element,str):
        print(isinstance(element,str))
        if element.isdigit():
            print(int(element)**2)
        else:
            print(f"{element} is not a number")
    else:
        print(f"{element} is not a string")
# Out:
# True
# Ahmad is not a number
# True
# 4
# True
# 49
# True
# python is not a number

# %%
#Dictionary

# %%
di = {"username":"Ahmad","gender":"Male","age":25,"hobby":"Coding"}

# %%
di
# Out:
# {'username': 'Ahmad', 'gender': 'Male', 'age': 25, 'hobby': 'Coding'}

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
di = {"name":[],"age":[]}

# %%
di = {"name":[],"age":[]}

# %%
print(di)
# Out:
# {'name': [], 'age': []}

# %%
di = {"name":[],"age":[]}

while True:
     nm = input("Enter your name: ")
     age = input("Enter your age: ")

     di["name"].append(nm)
     di["age"].append(age)

     choice = input("Want to add more person? (y/n):")
     if choice == "y":
         continue
     else:
         break

# %%
print(di)
# Out:
# {'name': ['Ahmad', 'Ali'], 'age': ['25', '26']}

# %%
"Ahmed"

# %%
if "Ahmad" in di["name"]:
    print("it exist")
else:
    print("it does not exist")
# Out:
# it exist

# %%
di2 = {"k1":"value1","k2":"value2","k3":"value3"}
li = ["value1","value2","value3"]

# %%
print(li[0])
print(di2["k1"])
# Out:
# value1
# value1

# %%
for i in li:
    print(i)
# Out:
# value1
# value2
# value3

# %%
for k in di2.values():
    print(k)
# Out:
# value1
# value2
# value3

# %%
priceDictionary = {"messyPrice":["100,00","200,00"],
                   "cleanedPrice":[]}

# %%
for price in priceDictionary["messyPrice"]:
    (priceDictionary["cleanedPrice"].
     append(int(price.replace(",",""))))

# %%
print(priceDictionary)
# Out:
# {'messyPrice': ['100,00', '200,00'], 'cleanedPrice': [10000, 20000]}

# %%
di = {"key1":"Value1","Key2":"Value2","Key3":"Value3"}
di["Key2"] = "Python"

# %%
di
# Out:
# {'key1': 'Value1', 'Key2': 'Python', 'Key3': 'Value3'}

# %%
di2={}
k = input("enter the name of key : ")
v = input("enter the value of key : ")
di2[k]=v

# %%
di2
userData = {}

# %%
# User Name , Gender , age, class, DOB

un = input("Enter your name: ")
ge = input("Enter your gender: ")
ag = input("Enter your age: ")
cl = input("Enter your class: ")
do = input("Enter your DOB:")


userData[un] = {"Gender":ge,"Age":ag,"Class":cl,"DOB":do}

# %%
userData = {"Ahmad":{"Gender":"Male","Age":25,"Class":"10th","DOB":"12/12/2000"}}

# %%
userData["Ali"]
# Out:
# ['Male', '20', 'asd', 'asdas']

# %%
import pandas as pd

df = pd.DataFrame(userData)
print(df)
# Out:
#     Ahmad    Ali
# 0    Male   Male
# 1      25     20
# 2  Python    asd
# 3    9asd  asdas

# %%
df
# Out:
#     Ahmad    Ali
# 0    Male   Male
# 1      25     20
# 2  Python    asd
# 3    9asd  asdas

# %%
li = [0,"Ahmad",2,3,4,5]

di = {"name":"Ahmad","age":25,"hobby":"Coding"}

# %%
print(li[1])
# Out:
# Ahmad

# %%
print(di["name"])
# Out:
# Ahmad

# %%
print(di["hobby"])
# Out:
# Coding

# %%
li = [1,2,[3,4,5,6]]
li[2][2]
# Out:
# 5

# %%
di = {"NumberList":[1,2,3,4,5],"name":"Ali"}

# %%
di["name"]
# Out:
# 'Ali'

# %%
print(di)
print(di["NumberList"])
di["NumberList"][-1]
# Out:
# {'NumberList': [1, 2, 3, 4, 5], 'name': 'Ali'}
# [1, 2, 3, 4, 5]
# 5

# %%
di2 = {"k1":["Ahmad","Ali"],"k2":{"nestedKey1":"nestedValue1","nestedKey2":"nestedValue2"}}

# %%
print(di2["k2"]["nestedKey2"])
# Out:
# nestedValue2

# %%
AD = {"nm":("Ahmad","Ali"),"ud":{"age":25,"gender":"Male","hobby":["PythonCode"]}}
# Print Ali , age and gender
# Append reading in hobby list

# %%
AD["ud"]["hobby"].append("Reading")
print(f"Name is {AD['nm'][1]} and age is {AD['ud']['age']} and gender is {AD['ud']['gender']}")
# Out:
# Name is Ali and age is 25 and gender is Male

# %%
AD["ud"]["hobby"] = "Reading"

# %%
di = {"k1":"v1","k2":"v2","k3":"v3"}
for i in di.values():
    print(i)
# Out:
# v1
# v2
# v3

# %%
di["k1"]
