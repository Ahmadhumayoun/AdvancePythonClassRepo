# %%
import pandas as pd
import requests as r

# %%
response = r.get("https://fake-json-api.mock.beeceptor.com/users")

# %%
# print(response.json())
userResponse = response.json()
userDatadf = pd.DataFrame(userResponse)

# %%
userDatadf
# Out:
#    id                                               name  \
# 0   1                                     Arely Emmerich
# 1   2  Paolo Faker Attribute Error: person.astName is...
# 2   3                                      Juliet Walker
# 3   4                                       Tyrell Rohan
# 4   5                                        Aglae Berge
# 5   6                                   Stephan Schulist
# 6   7                                        Adell Mills
# 7   8                                    Brandyn Hegmann
# 8   9                                   Rachelle Schaden
# 9  10                                     Sigmund Gibson
#
#                  company               username                         email  \
# 0            Johnson Inc           Eliza_Fisher           Camilla51@gmail.com
# 1       Shields and Sons  Kristopher_Macejkovic              Kaya63@gmail.com
# 2      Reilly - Turcotte       Lorenzo_MacGyver  Elenora.Sporer54@hotmail.com
# 3         Harvey - Lesch      Pascale.Goldner15      Cloyd_Glover27@yahoo.com
# 4              Doyle Inc        Dorothea_Veum27    Drew.VonRueden93@gmail.com
# 5         Adams - Hammes          Johan.Nader26    Leonard_MacGyver@gmail.com
# 6           Rice - Sipes                 Arch39    Raymundo_Price31@gmail.com
# 7  Christiansen - Hessel              Stephon69             Jordy45@gmail.com
# 8           Emmerich LLC          Lester.Pouros        John_Berge17@gmail.com
# 9         Corwin - Wolff          Kaci.Prosacco       Stuart.Torp75@yahoo.com
#
#                    address         zip           state  \
# 0    61981 Franklin Avenue       78269           Texas
# 1        2417 Evert Greens  37297-4294          Hawaii
# 2     6206 Helen Junctions       67143   West Virginia
# 3        154 Leland Greens       01884          Alaska
# 4        67363 DuBuque Via       64879         Indiana
# 5    52737 Ibrahim Parkway       48626        Oklahoma
# 6       31400 Verna Estate  74984-3077        Illinois
# 7  705 Pfannerstill Tunnel       42497  South Carolina
# 8        689 Dovie Freeway       57772      New Jersey
# 9        888 Camden Plains       85706        Missouri
#
#                                  country                  phone  \
# 0                                   Fiji   (960) 976-5813 x0828
# 1                                 Zambia  (344) 631-2081 x49211
# 2                    Trinidad and Tobago     409-725-0372 x3336
# 3                                 Canada   1-506-521-5857 x5873
# 4                          Aland Islands         (495) 844-7002
# 5                                 Israel      237.582.3444 x987
# 6                                 Brazil     686.650.3896 x8426
# 7                                  Japan     976.791.7053 x5404
# 8  Lao People&#x27;s Democratic Republic  (656) 625-2762 x53423
# 9                             Martinique     429-453-0486 x6734
#
#                                         photo
# 0  https://json-server.dev/ai-profiles/59.png
# 1  https://json-server.dev/ai-profiles/43.png
# 2  https://json-server.dev/ai-profiles/86.png
# 3  https://json-server.dev/ai-profiles/78.png
# 4  https://json-server.dev/ai-profiles/28.png
# 5  https://json-server.dev/ai-profiles/22.png
# 6  https://json-server.dev/ai-profiles/71.png
# 7  https://json-server.dev/ai-profiles/59.png
# 8  https://json-server.dev/ai-profiles/65.png
# 9   https://json-server.dev/ai-profiles/8.png

# %%
url = 'https://api.escuelajs.co/api/v1/auth/login'
h = {
    'Content-Type': 'application/json'
}
accesToken = ""
credentials = {"email":"john@mail.com","password":"changeme"}
response = r.post(url,json = credentials,headers=h)
print(response.json())
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ4NjYwNiwiZXhwIjoxNzc3MjE0NjA2fQ.kTnnouuqwkbgreK7HpRemRQfPbu9BnLXmiZ-dNrC1aQ', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ4NjYwNiwiZXhwIjoxNzc1NTIyNjA2fQ.pVnliX7UIKSb1vvvXrL3KkogZdEuRflxfskpzJpVkiE'}

# %%
userProfileUrl = "https://api.escuelajs.co/api/v1/auth/profile"
newHeader = "Authorization: Bearer {your_access_token}"
