# %%
import requests as r
# Out:
# /Users/muhammadahmadhumayoun/PyCharmMiscProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
response = r.get("https://fake-json-api.mock.beeceptor.com/users")

# %%
# print(response.json())
userResponse = response.json()
for i in userResponse:
    print(i)
# Out:
# {'id': 1, 'name': 'Sylvan Maggio', 'company': 'Nitzsche Inc', 'username': 'Lorenzo53', 'email': 'Mozelle.Hand14@hotmail.com', 'address': '5997 Market Square', 'zip': '20154', 'state': 'Michigan', 'country': 'Afghanistan', 'phone': '(466) 496-9860', 'photo': 'https://json-server.dev/ai-profiles/39.png'}
# {'id': 2, 'name': 'Beverly Faker Attribute Error: person.astName is not supported', 'company': 'Schamberger, Nolan and Windler', 'username': 'Rosalinda76', 'email': 'Charlie15@yahoo.com', 'address': '68045 Mitchell Freeway', 'zip': '16511-8933', 'state': 'Delaware', 'country': 'Barbados', 'phone': '298-243-9838', 'photo': 'https://json-server.dev/ai-profiles/23.png'}
# {'id': 3, 'name': 'Remington Abernathy', 'company': 'Considine, Hills and Sawayn', 'username': 'Carlee_Strosin', 'email': 'Sedrick_Bayer15@gmail.com', 'address': '90969 Harber Trail', 'zip': '33141', 'state': 'Wisconsin', 'country': 'Tonga', 'phone': '(704) 322-0358 x0421', 'photo': 'https://json-server.dev/ai-profiles/38.png'}
# {'id': 4, 'name': 'Logan Vandervort', 'company': 'Parisian and Sons', 'username': 'Hudson.Bogisich', 'email': 'Freeman_Raynor23@gmail.com', 'address': '204 Church Lane', 'zip': '35826-2289', 'state': 'Rhode Island', 'country': 'Bangladesh', 'phone': '(939) 464-8415 x592', 'photo': 'https://json-server.dev/ai-profiles/51.png'}
# {'id': 5, 'name': 'Delia Bednar', 'company': 'Bergstrom Group', 'username': 'Hayden.Witting', 'email': 'Alek31@yahoo.com', 'address': '9325 Wintheiser Spring', 'zip': '08444', 'state': 'South Carolina', 'country': 'Spain', 'phone': '736-881-3700', 'photo': 'https://json-server.dev/ai-profiles/52.png'}
# {'id': 6, 'name': 'Noah Aufderhar', 'company': 'Hackett, Marks and Padberg', 'username': 'Robb_Hackett37', 'email': 'Nikko.Deckow30@yahoo.com', 'address': '167 W 11th Street', 'zip': '97068', 'state': 'Idaho', 'country': 'Wallis and Futuna', 'phone': '767-785-0325 x716', 'photo': 'https://json-server.dev/ai-profiles/73.png'}
# {'id': 7, 'name': 'Katelin Christiansen', 'company': 'Runolfsson, Bradtke and Gerlach', 'username': 'Maybelle38', 'email': 'Kiana28@gmail.com', 'address': '6129 Ida Valleys', 'zip': '52492-7944', 'state': 'Rhode Island', 'country': 'Spain', 'phone': '(447) 309-8196 x908', 'photo': 'https://json-server.dev/ai-profiles/13.png'}
# {'id': 8, 'name': 'Ruthe Rohan', 'company': 'Tromp, Emmerich and Sawayn', 'username': 'Name.Gottlieb4', 'email': 'Savannah.Daniel@gmail.com', 'address': '729 Lueilwitz Inlet', 'zip': '47784', 'state': 'Oklahoma', 'country': 'Lithuania', 'phone': '639.221.5656', 'photo': 'https://json-server.dev/ai-profiles/35.png'}
# {'id': 9, 'name': 'Valentine Parisian', 'company': 'Ferry, Kuphal and Hudson', 'username': 'Alexie_Kutch63', 'email': 'Beryl.OKeefe@yahoo.com', 'address': '55837 Fisher Parks', 'zip': '72618', 'state': 'Mississippi', 'country': 'Jordan', 'phone': '459-732-6431 x241', 'photo': 'https://json-server.dev/ai-profiles/97.png'}
# {'id': 10, 'name': 'Doris Bednar', 'company': 'Rosenbaum LLC', 'username': 'Noemy.Grady', 'email': 'Fern_Casper65@hotmail.com', 'address': '3768 Mann Mill', 'zip': '25356-5356', 'state': 'Alaska', 'country': 'Suriname', 'phone': '702.583.7389', 'photo': 'https://json-server.dev/ai-profiles/91.png'}
