# %%
# Number Addtion
import pandas as pd



def cleanPrice(listOfPrice, itemToClean):
    cleanedPrice = []
    for i in range(len(listOfPrice)):
        listOfPrice[i] = listOfPrice[i].replace(itemToClean, "")
        cleanedPrice.append(listOfPrice[i])
    return cleanedPrice

# %%
itemSheet = pd.read_excel("/Users/muhammadahmadhumayoun/Downloads/GithubTutorial/AdvancePythonClass/AdvancePythonClassRepo/PandasTabularData/VendorProducts.xlsx",sheet_name="Items")
collectionsSheet = pd.read_excel("/Users/muhammadahmadhumayoun/Downloads/GithubTutorial/AdvancePythonClass/AdvancePythonClassRepo/PandasTabularData/VendorProducts.xlsx",sheet_name="Collections")

# %%
itemSheet
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
collectionsSheet
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name Color Code       Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420,000د.ع
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300,000د.ع
# 2                              The Glow Stick    #F3D5C6   19,750د.ع
# ...

# %%
collectionsSheet.drop(columns=["Color Code","Unit Level","Is Active"],inplace=True)

# %%
collectionsSheet
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name       Price        Barcode  \
# 0            Bleu De Chanel L'Exclusif Parfum  420,000د.ع  3145891072204
# 1            Bleu De Chanel L'Exclusif Parfum  300,000د.ع  3145891072105
# 2                              The Glow Stick   19,750د.ع  7333352079169
# ...

# %%
itemSheet.drop(columns=["Sub Description","Secondary Sub Description","Code"],inplace=True)

# %%
itemSheet
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
collectionsSheet["Item Name"] = collectionsSheet["Item Name"] + " " + collectionsSheet["Color"]
collectionsSheet["Secondary Item Name"] = collectionsSheet["Secondary Item Name"] + " " + collectionsSheet["Secondary Color"]

# %%
collectionsSheet
# Out:
#        Item Id                                     Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد 100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد 50 مل
# 2       364804                 هايلايتر ستك 24 سباركلينج بيج
# 3       364804                      هايلايتر ستك 25 روز جليم
# 4       364793                                 كونتور ستك 30
# ...        ...                                           ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل 03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي 500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي 88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف 500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف 88.7 مل
#
#                                   Secondary Item Name       Price  \
# 0             Bleu De Chanel L'Exclusif Parfum 100 ml  420,000د.ع
# 1              Bleu De Chanel L'Exclusif Parfum 50 ml  300,000د.ع
# ...

# %%
collectionsSheet.drop(columns=["Color","Secondary Color","Size"],inplace=True)

# %%
collectionsSheet.drop(columns=["Code"],inplace=True)

# %%
collectionsSheet
# Out:
#        Item Id                                     Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد 100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد 50 مل
# 2       364804                 هايلايتر ستك 24 سباركلينج بيج
# 3       364804                      هايلايتر ستك 25 روز جليم
# 4       364793                                 كونتور ستك 30
# ...        ...                                           ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل 03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي 500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي 88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف 500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف 88.7 مل
#
#                                   Secondary Item Name       Price  \
# 0             Bleu De Chanel L'Exclusif Parfum 100 ml  420,000د.ع
# 1              Bleu De Chanel L'Exclusif Parfum 50 ml  300,000د.ع
# ...

# %%
newPrice = cleanPrice(list(collectionsSheet["Price"]), ",")
newPrice = cleanPrice(newPrice,"د.ع")

# %%
collectionsSheet["Price"] = newPrice

# %%
collectionsSheet
# Out:
#        Item Id                                     Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد 100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد 50 مل
# 2       364804                 هايلايتر ستك 24 سباركلينج بيج
# 3       364804                      هايلايتر ستك 25 روز جليم
# 4       364793                                 كونتور ستك 30
# ...        ...                                           ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل 03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي 500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي 88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف 500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف 88.7 مل
#
#                                   Secondary Item Name   Price        Barcode  \
# 0             Bleu De Chanel L'Exclusif Parfum 100 ml  420000  3145891072204
# ...

# %%
itemSheet
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
newPrice = cleanPrice(list(itemSheet["Price"]), ",")
newPrice = cleanPrice(newPrice,"د.ع")

# %%
itemSheet["Price"] = newPrice

# %%
itemSheet
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
collectionsSheet
# Out:
#        Item Id                                     Item Name  \
# 0       390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد 100 مل
# 1       390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد 50 مل
# 2       364804                 هايلايتر ستك 24 سباركلينج بيج
# 3       364804                      هايلايتر ستك 25 روز جليم
# 4       364793                                 كونتور ستك 30
# ...        ...                                           ...
# 14481   332027      كونسيلر فوري مضاد للشيخوخة 6 مل 03 معتدل
# 14482   316612   غسول الفم للثة الصحية بالنعناع النقي 500 مل
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي 88.7 مل
# 14484   316610           غسول فم منعش بالنعناع الخفيف 500 مل
# 14485   316610          غسول فم منعش بالنعناع الخفيف 88.7 مل
#
#                                   Secondary Item Name   Price        Barcode  \
# 0             Bleu De Chanel L'Exclusif Parfum 100 ml  420000  3145891072204
# ...

# %%
itemSheet
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991
#
#                                                    Name  \
# 0                            زيت الشفاه بليجر 001، 5 مل
# 1                  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
collectionsSheet.rename(columns={"Item Name":"Name","Secondary Item Name":"Secondary Name","Item Id":"Id",},inplace=True)

# %%
collectionsSheet
# Out:
#            Id                                          Name  \
# 0      390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد 100 مل
# 1      390187    عطر بلو دي شانيل لي اكسكلوسيف الجديد 50 مل
# 2      364804                 هايلايتر ستك 24 سباركلينج بيج
# 3      364804                      هايلايتر ستك 25 روز جليم
# 4      364793                                 كونتور ستك 30
# ...       ...                                           ...
# 14481  332027      كونسيلر فوري مضاد للشيخوخة 6 مل 03 معتدل
# 14482  316612   غسول الفم للثة الصحية بالنعناع النقي 500 مل
# 14483  316612  غسول الفم للثة الصحية بالنعناع النقي 88.7 مل
# 14484  316610           غسول فم منعش بالنعناع الخفيف 500 مل
# 14485  316610          غسول فم منعش بالنعناع الخفيف 88.7 مل
#
#                                        Secondary Name   Price        Barcode  \
# 0             Bleu De Chanel L'Exclusif Parfum 100 ml  420000  3145891072204
# 1              Bleu De Chanel L'Exclusif Parfum 50 ml  300000  3145891072105
# ...

# %%
collectionsSheet.loc[collectionsSheet["Id"]==390187,"Secondary Name"]
# Out:
# 0    Bleu De Chanel L'Exclusif Parfum 100 ml
# 1     Bleu De Chanel L'Exclusif Parfum 50 ml
# Name: Secondary Name, dtype: object

# %%
for eachId in list(collectionsSheet["Id"]):
    if eachId in list(itemSheet["Id"]):
        #===============#
        Picture = collectionsSheet.loc[collectionsSheet["Id"]==eachId,"Picture"].values[0]
        Id = collectionsSheet.loc[collectionsSheet["Id"]==eachId,"Id"].values[0]
        Name = collectionsSheet.loc[collectionsSheet["Id"]==eachId,"Name"].values[0]
        SecondaryName = collectionsSheet.loc[collectionsSheet["Id"]==eachId,"Secondary Name"].values[0]
        Price = collectionsSheet.loc[collectionsSheet["Id"]==eachId,"Price"].values[0]
        mBarcode = collectionsSheet.loc[collectionsSheet["Id"]==eachId,"Barcode"].values[0]
        #===============#
        Description = itemSheet.loc[itemSheet["Id"]==eachId,"Description"].values[0]
        SecondaryDescription = itemSheet.loc[itemSheet["Id"]==eachId,"Secondary Description"].values[0]
        Menu = itemSheet.loc[itemSheet["Id"]==eachId,"Menu"].values[0]
        Brand = itemSheet.loc[itemSheet["Id"]==eachId,"Brand"].values[0]
        SecondaryBrand =itemSheet.loc[itemSheet["Id"]==eachId,"Secondary Brand"].values[0]
        HasCollection = True
        #===============#
        finaLRow = [Picture,Id,Name,SecondaryName,mBarcode,Price,Description,SecondaryDescription,Menu,Brand,SecondaryBrand,HasCollection]
        currentrowNumber = len(itemSheet["Id"])
        itemSheet.loc[currentrowNumber] = finaLRow

# %%
itemSheet
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 39183  https://www.storeakmedia.com/storeak-erp/Store...  332027
# 39184  https://www.storeakmedia.com/storeak-erp/Store...  316612
# 39185  https://www.storeakmedia.com/storeak-erp/Store...  316612
# 39186                                                NaN  316610
# 39187                                                NaN  316610
#
#                                               Name  \
# 0                       زيت الشفاه بليجر 001، 5 مل
# 1             عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...

# %%
itemSheet.to_csv("FinalItemSheet.csv",index=False)

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
with open("PageSource.txt","r",encoding="utf-8") as f:
    sourceCode = f.read()
    s = bs(sourceCode,"html.parser")
    # s = s.prettify()
    countryData ={"Country Name": [], "Country Capital": [], "Country Population": [], "Country Area": []}
    countryNames = s.find_all("h3",{"class":"country-name"})
    countrycapitals = s.find_all("span", {"class": "country-capital"})
    countrypopulation = s.find_all("span", {"class": "country-population"})
    countryArea = s.find_all("span", {"class": "country-area"})
    for i in range(len(countryNames)):
        countryData["Country Name"].append(countryNames[i].text.strip())
        countryData["Country Capital"].append(countrycapitals[i].text.strip())
        countryData["Country Population"].append(countrypopulation[i].text.strip())
        countryData["Country Area"].append(countryArea[i].text.strip())

# %%
countryInfodf = pd.DataFrame(countryData)

# %%
countryInfodf
# Out:
#              Country Name   Country Capital Country Population Country Area
# 0                 Andorra  Andorra la Vella              84000        468.0
# 1    United Arab Emirates         Abu Dhabi            4975593      82880.0
# 2             Afghanistan             Kabul           29121286     647500.0
# 3     Antigua and Barbuda        St. John's              86754        443.0
# 4                Anguilla        The Valley              13254        102.0
# ..                    ...               ...                ...          ...
# 245                 Yemen             Sanaa           23495361     527970.0
# 246               Mayotte         Mamoudzou             159042        374.0
# 247          South Africa          Pretoria           49000000    1219912.0
# 248                Zambia            Lusaka           13460305     752614.0
# 249              Zimbabwe            Harare           11651858     390580.0
#
# [250 rows x 4 columns]

# %%
countryInfodf.to_csv("CountryInfo.csv",index=False)
